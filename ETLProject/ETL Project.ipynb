# %%
import pandas as pd

# %%
# Read in csv files
songs = pd.read_csv("Songs.csv", encoding='ISO-8859-1')
netflix = pd.read_csv("netflix_titles.csv")

# %%
netflix.head()
# Out:
#     show_id     type                                    title  \
# 0  81145628    Movie  Norm of the North: King Sized Adventure
# 1  80117401    Movie               Jandino: Whatever it Takes
# 2  70234439  TV Show                       Transformers Prime
# 3  80058654  TV Show         Transformers: Robots in Disguise
# 4  80125979    Movie                             #realityhigh
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4          Fernando Lebrija
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
# 2  Peter Cullen, Sumalee Montano, Frank Welker, J...
# 3  Will Friedle, Darren Criss, Constance Zimmer, ...
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...
#
#                                     country date_added  release_year  \
# ...

# %%
# Delete columns
del netflix['show_id']
del netflix['director']
del netflix['cast']
del netflix['date_added']
del netflix['description']

# %%
netflix.head()
# Out:
#       type                                    title  \
# 0    Movie  Norm of the North: King Sized Adventure
# 1    Movie               Jandino: Whatever it Takes
# 2  TV Show                       Transformers Prime
# 3  TV Show         Transformers: Robots in Disguise
# 4    Movie                             #realityhigh
#
#                                     country  release_year    rating  duration  \
# 0  United States, India, South Korea, China          2019     TV-PG    90 min
# 1                            United Kingdom          2016     TV-MA    94 min
# 2                             United States          2013  TV-Y7-FV  1 Season
# 3                             United States          2016     TV-Y7  1 Season
# 4                             United States          2017     TV-14    99 min
#
#                             listed_in
# 0  Children & Family Movies, Comedies
# 1                     Stand-Up Comedy
# 2                            Kids' TV
# ...

# %%
# Categorize by year
twenty19 = netflix.loc[netflix['release_year'] == 2019]
twenty18 = netflix.loc[netflix['release_year'] == 2018]
twenty17 = netflix.loc[netflix['release_year'] == 2017]
twenty16 = netflix.loc[netflix['release_year'] == 2016]
twenty15 = netflix.loc[netflix['release_year'] == 2015]
twenty14 = netflix.loc[netflix['release_year'] == 2014]

# %%
twenty19
# Out:
#          type                                              title  \
# 0       Movie            Norm of the North: King Sized Adventure
# 34    TV Show                         Archibald's Next Big Thing
# 35      Movie                                         Article 15
# 38      Movie                                Kill Me If You Dare
# 39    TV Show                                            The Spy
# 44      Movie   American Factory: A Conversation with the Obamas
# 57      Movie                                  The World We Make
# 58      Movie                                           Watchman
# 62      Movie                              Mo Gilligan: Momentum
# 86      Movie  Cultivating the Seas: History and Future of th...
# 87      Movie                                             Domino
# 88      Movie                                          TUNA GIRL
# 99    TV Show                                      Bard of Blood
# ...

# %%
# Categorize by number of seasons
oneSeason = netflix.loc[netflix['duration'] == '1 Season']
twoSeasons = netflix.loc[netflix['duration'] == '2 Seasons']
threeSeasons = netflix.loc[netflix['duration'] == '3 Seasons']
fourSeasons = netflix.loc[netflix['duration'] == '4 Seasons']
fiveSeasons = netflix.loc[netflix['duration'] == '5 Seasons']
sixSeasons = netflix.loc[netflix['duration'] == '6 Seasons']
sevenSeasons = netflix.loc[netflix['duration'] == '7 Seasons']
eightSeasons = netflix.loc[netflix['duration'] == '8 Seasons']

# %%
eightSeasons
# Out:
#          type                                title                country  \
# 5593  TV Show                  The Vampire Diaries          United States
# 5605  TV Show                           Portlandia          United States
# 5607  TV Show                American Horror Story          United States
# 5700  TV Show                              Charmed          United States
# 5737  TV Show            Trolls: The Beat Goes On!          United States
# 5754  TV Show  My Little Pony: Friendship Is Magic  United States, Canada
# 5771  TV Show                       That '70s Show          United States
# 5810  TV Show                          Royal Pains          United States
# 5814  TV Show                     Call the Midwife         United Kingdom
# 5980  TV Show               The Andy Griffith Show          United States
# 6023  TV Show                               Dexter          United States
# 6052  TV Show             Club Friday The Series 8                    NaN
# ...

# %%
#Categorize by Rating
G = netflix.loc[netflix['rating'] == 'G']
NC17 = netflix.loc[netflix['rating'] == 'NC-17']
NR = netflix.loc[netflix['rating'] == 'NR']
PG = netflix.loc[netflix['rating'] == 'PG']
PG13 = netflix.loc[netflix['rating'] == 'PG-13']
R = netflix.loc[netflix['rating'] == 'R']
TV14 = netflix.loc[netflix['rating'] == 'TV-14']
TVG = netflix.loc[netflix['rating'] == 'TV-G']
TVMA = netflix.loc[netflix['rating'] == 'TV-MA']
TVPG = netflix.loc[netflix['rating'] == 'TV-PG']
TVY = netflix.loc[netflix['rating'] == 'TV-Y']
TVY7 = netflix.loc[netflix['rating'] == 'TV-Y7']
TVY7FV = netflix.loc[netflix['rating'] == 'TV-Y7-FV']

# %%
PG13
# Out:
#        type                                             title  \
# 23    Movie                                Stonehearst Asylum
# 31    Movie                         Sierra Burgess Is A Loser
# 59    Movie                                     Black Panther
# 110   Movie                                   The Grandmaster
# 112   Movie                               The Hurricane Heist
# 137   Movie                              20 Feet From Stardom
# 141   Movie                                  SMOSH: The Movie
# 144   Movie                                       Sarah's Key
# 176   Movie                                        Miss Julie
# 208   Movie                       Scott Pilgrim vs. the World
# 294   Movie                                     Eat Pray Love
# 301   Movie                                      Dante's Peak
# 306   Movie                                      Just Friends
# 309   Movie                                      Mr. Woodcock
# ...

# %%
songs.head()
# Out:
#                             title  \
# 0            Like a Rolling Stone
# 1  (I Can't Get No) Satisfaction'
# 2                         Imagine
# 3                 What's Going On
# 4                         Respect
#
#                                          description  \
# 0  "I wrote it. I didn't fail. It was straight," ...
# 1  "It's the riff heard round the world," says St...
# 2  John Lennon wrote "Imagine," his greatest musi...
# 3  "What's Going On" is an exquisite plea for pea...
# 4  Otis Redding wrote "Respect" and recorded it f...
#
#                                           appears on              artist  \
# 0                    Highway 61 Revisited (Columbia)           Bob Dylan
# 1                           Out of Our Heads (ABKCO)  The Rolling Stones
# 2                            Imagine (Capitol/Apple)         John Lennon
# 3                            What's Going On (Tamla)         Marvin Gaye
# ...

# %%
del songs['description']
del songs['writers']
del songs['producer']
del songs['appears on']

# %%
songs.head()
# Out:
#                             title              artist    Month  Year  \
# 0            Like a Rolling Stone           Bob Dylan     July  1965
# 1  (I Can't Get No) Satisfaction'  The Rolling Stones      May  1965
# 2                         Imagine         John Lennon  October  1971
# 3                 What's Going On         Marvin Gaye      Feb  1971
# 4                         Respect     Aretha Franklin    April  1967
#
#      streak position
# 0  12 weeks    No. 2
# 1  14 weeks    No. 1
# 2   9 weeks    No. 3
# 3  13 weeks    No. 2
# 4  12 weeks    No. 1

# %%
# Categorize by month
Jan = songs.loc[songs['Month'] == 'Jan']
Feb = songs.loc[songs['Month'] == 'Feb']
Mar = songs.loc[songs['Month'] == 'March']
Apr = songs.loc[songs['Month'] == 'April']
May = songs.loc[songs['Month'] == 'May']
June = songs.loc[songs['Month'] == 'June']
July = songs.loc[songs['Month'] == 'July']
Aug = songs.loc[songs['Month'] == 'Aug']
Sept = songs.loc[songs['Month'] == 'Sept']
Oct = songs.loc[songs['Month'] == 'Oct']
Nov = songs.loc[songs['Month'] == 'Nov']
Dec = songs.loc[songs['Month'] == 'Dec']

# %%
Mar
# Out:
#                                         title                       artist  \
# 16                                Purple Haze  The Jimi Hendrix Experience
# 19                                  Let It Be                  The Beatles
# 156                                     Rehab                Amy Winehouse
# 161  I Never Loved a Man (the Way I Love You)              Aretha Franklin
# 180                        Losing My Religion                       R.E.M.
# 185                      Nothing Compares 2 U              Sinead O'Connor
# 189                    Im Waiting for the Man       The Velvet Underground
# 190                       Moment of Surrender                           U2
# 247                                     Loser                         Beck
# 438                                  Umbrella      Rihanna Featuring Jay-Z
#
#      Month  Year      streak position
# 16   March  1967     8 weeks   No. 65
# 19   March  1970    14 weeks    No. 1
# ...

# %%
# Categorize by year
twenty08 = songs.loc[songs['Year'] == 2008]
twenty07 = songs.loc[songs['Year'] == 2007]
twenty06 = songs.loc[songs['Year'] == 2006]
twenty05 = songs.loc[songs['Year'] == 2005]
twenty04 = songs.loc[songs['Year'] == 2004]

# %%
twenty04
# Out:
#                  title           artist  Month  Year    streak position
# 277        Jesus Walks       Kanye West  Feb.   2004  25 weeks   No. 11
# 323        Take Me Out  Franz Ferdinand  Feb.   2004  19 weeks   No. 66
# 364               Maps  Yeah Yeah Yeahs  Feb.   2004  13 weeks   No. 87
# 418     American Idiot        Green Day  Oct.   2004  20 weeks   No. 61
# 468  Since U Been Gone   Kelly Clarkson  Nov.   2004  46 weeks    No. 2

# %%
#Categorize by weeks on the charts (top 5)
streak = songs.loc[songs['streak'] == '46 weeks']
streak2 = songs.loc[songs['streak'] == '42 weeks']
streak3 = songs.loc[songs['streak'] == '39 weeks']
streak4 = songs.loc[songs['streak'] == '33 weeks']
streak5 = songs.loc[songs['streak'] == '32 weeks']

# %%
streak
# Out:
#                  title          artist  Month  Year    streak position
# 468  Since U Been Gone  Kelly Clarkson  Nov.   2004  46 weeks    No. 2

# %%
#Categorize by position on charts (top 5)
no1 = songs.loc[songs['position'] == ' No. 1']
no2 = songs.loc[songs['position'] == ' No. 2']
no3 = songs.loc[songs['position'] == ' No. 3']
no4 = songs.loc[songs['position'] == ' No. 4']
no5 = songs.loc[songs['position'] == ' No. 5']

# %%
no1
# Out:
#                                         title                         artist  \
# 57   I Still Havent Found What Im Looking For                             U2
# 59                           Suspicious Minds                  Elvis Presley
# 62                                    My Girl                The Temptations
# 69           I Heard It Through the Grapevine                    Marvin Gaye
# 71                         Mr. Tambourine Man                      The Byrds
# 77                               Superstition                  Stevie Wonder
# 86                              She Loves You                    The Beatles
# 90                         Lets Stay Together                       Al Green
# 92                                Billie Jean                Michael Jackson
# 107  I Still Havent Found What Im Looking For                             U2
# 109                          Suspicious Minds                  Elvis Presley
# ...

# %%
from sqlalchemy import create_engine
engine = create_engine("postgres://postgres:Gamecock2020!@localhost:5432/ETLProject")

# %%
#Netflix tables
twenty19.to_sql("2019 Movies/TV Shows", engine)
fiveSeasons.to_sql("TV shows with 5 seasons", engine)
R.to_sql("R rated movies", engine)

# %%
# Song tables
Mar.to_sql("Songs released in March", engine)
twenty05.to_sql("Songs that came out in 2005", engine)
streak.to_sql("Song(s) that were on the charts for 46 weeks", engine)
no1.to_sql("Songs that reached #1 on the charts", engine)
